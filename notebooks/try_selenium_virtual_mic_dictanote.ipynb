# %%
from selenium.webdriver.chrome.options import Options

options = Options()
options.add_argument("--guest")
# options.add_argument("--use-fake-ui-for-media-stream")  # tự động cho phép mic
# options.add_argument("--allow-file-access-from-files")
# options.add_argument("--use-fake-device-for-media-stream") # nếu cần fake mic
# options.add_argument("--auto-select-desktop-capture-source=VirtualMic") # chỉ định mic ảo

# %%
import undetected_chromedriver as uc
from selenium.webdriver.common.by import By
import time

driver = uc.Chrome(options=options)
driver.get("https://dictanote.co/#/n/0/")
time.sleep(5)  # đợi web load

# %%
# Tìm button mic và click
mic_button = driver.find_element(By.CSS_SELECTOR, "button[aria-label='Start/Stop Voice Typing']")
mic_button.click()

# %%
driver.quit()
